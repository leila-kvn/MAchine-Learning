# %%
#Regression

import numpy as np
import matplotlib.pyplot as plt

x=np.random.normal(3,1,100)
y=100-(x+np.random.normal(0,0.1,100))*3

plt.scatter(x,y)
def predict(x):
    return -3*x+100

fitline=predict(x)
plt.plot(x,fitline,c='b')
plt.show()
